# %% [markdown]
# ## 실습1) HTML(res.text)데이터 가져오기

# %% [markdown]
# ### 네이버 철강용어사전 용어 가져오기

# %% [markdown]
#  - requests 모듈을 이용해 네이버 철강용어사전 접속하기
#  - 표제어들의 제목 출력하기
#  - 링크 : https://terms.naver.com/list.naver?cid=67995&categoryId=67995

# %% [markdown]
# #### 철강용어사전 1page 단어 타이틀 정보 가져오기

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs4

url = 'https://terms.naver.com/list.naver'
p = {'cid': '67995', 'categoryId' : '67995'}
res = requests.get(url, params=p)
soup=bs4(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-agent="python-requests/2.31.0" lang="ko">
# <head>
# <link href="https://terms.naver.com/" rel="canonical"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="requiresActiveX=true;IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="article" property="og:type"/>
# <meta content="https://terms.naver.com/list.naver?cid=67995&amp;categoryId=67995" property="og:url"/>
# <meta content="철강용어사전 : 네이버 지식백과" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/terms/common/img/og.png" property="og:image"/>
# <meta content="제1류위험물, 연신율, 제연설비, 연결살수설비, 특정잔류탄소함유율탈탄층깊이, 재고회전율, 선재, 제4류위험물, 슬리터, 후판, 자위소방대, 핀홀, Top-Down공법, 옥내소화전설" property="og:description"/>
# <meta content="네이버 지식백과" property="og:article:author">
# <meta content="https://m.terms.naver.com" property="og:article:author:url">
# <meta content="width=1110" name="viewport">
# <title>철강용어사전 : 네이버 지식백과</title>
# <meta content="어린이/학생백과, 동물/식물, 건강, 역사, 자연과학, 인문과학, 미술작품, 비주얼사전 등 전문가들이 정리한 지식을 제공하는 종합백과서비스" name="Description">
# <link href="https://ssl.pstatic.net/static/terms/terms/css/terms_tlist.css?240213064516" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static/terms/terms/css/terms_230427.css?240213064516" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?240213064516" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static/maps/openapi_map/maps_openapi.css?240213064516" rel="stylesheet" type="text/css"/>
# </meta></meta></meta></meta></head>
# <body class="" id="termBody">
# <div class="" id="wrap">
# <div id="u_skip">
# <a href="#gnb" onclick="document.getElementById('gnb').tabIndex=-1;document.getElementById('gnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#nav" onclick="document.getElementById('nav').tabIndex=-1;document.getElementById('nav').focus();return false;"><span>주제분류 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header" role="banner">
# <div class="gnb_wrap">
# <div class="gnb_area">
# <div class="site_area">
# <ul class="site_list">
# <li><a class="logo_openlectures" href="http://openlectures.naver.com/" onclick="nclk(this, 'rsv.openlt', '', '', 1);" target="_blank"><span class="blind">열린연단</span></a></li>
# <li><a class="logo_library" href="/list.naver?cid=44623&amp;categoryId=63167" onclick="nclk(this, 'rsv.imagelibrary', '', '', 1);"><span class="blind">이미지 라이브러리</span></a></li>
# <li><a class="logo_dic" href="http://dic.naver.com/" onclick="nclk(this, 'rsv.dic', '', '', 1);" target="_blank"><span class="blind">사전</span></a></li>
# </ul>
# <div class="login_area" id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2024031115" type="text/javascript"></script>
# <script type="text/javascript">gnb_brightness=3;window.attachEvent?window.attachEvent("onload",getGNB):window.addEventListener("load",getGNB,false);</script>
# </div>
# </div>
# </div>
# <div class="header_area" id="nav">
# <iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:54px;border:none;vertical-align:bottom;filter:alpha(opacity=0)" title="헤더"></iframe>
# <h1 class="service">
# <a class="logo_naver" href="https://www.naver.com/" onclick="nclk(this, 'STA.naverlogo', '', '', 1);"><span class="blind">NAVER</span></a>
# <a class="logo_terms" href="/" onclick="nclk(this, 'STA.terms', '', '', 1);"><span class="blind">지식백과</span></a>
# </h1>
# <div class="search_wrap">
# <form action="/search.naver" id="terms_search_form" method="get" name="search">
# <fieldset>
# <legend>지식백과 검색</legend>
# <div class="search_area">
# <div class="search_box" id="searchBox">
# <input accesskey="s" autocomplete="off" class="search_input" id="term_query" maxlength="100" name="query" title="검색" type="text" value=""/>
# <a class="btn_updn _toggle" href="#" role="button">
# <i class="icon"></i>
# <span class="blind _toggleIcon">자동완성 펼치기</span>
# </a>
# <!-- 자동완성 -->
# <div class="ly_auto" style="">
# <iframe class="bug_fix" frameborder="0" src="about:blank" style="filter:alpha(opacity=0)" title="버그픽스용" width="100%"></iframe>
# <div class="wrap" id="atcmp">
# <div class="words top _resultArea" style="display:none;">
# <ul class="_resultBox1">
# <!-- 			<li><a href="#" onclick="nclk(this, 'sch.autoclick', '', '@rank@', 1); return false;">@txt@</a><span style="display:none">@in_txt@</span></li> -->
# </ul>
# </div>
# <div class="words _noticeArea">
# <p class="msg co_basis_txt">
# 			현재 자동완성 기능을 사용하고 계십니다.
# 		</p>
# </div>
# <p class="func">
# <span>
# <a href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="parent.nclk(this,'sch.help','','', 1);" target="_blank">도움말</a> | <a class="funoff _off" href="#" onclick="nclk(this, 'sch.autooff', '', '', 1);return false;">자동완성 끄기</a>
# </span>
# </p>
# <span class="atcmp_helper">기능을 다시 켤 때는 <span class="point">검색창</span>을 클릭하세요</span>
# </div></div>
# <!-- //자동완성 -->
# </div>
# <input class="btn_search _search" onclick="nclk(this, 'sch.search', '', '', 1);" type="submit" value="검색"/>
# <input name="searchType" type="hidden" value=""/>
# <input name="dicType" type="hidden" value=""/>
# <input name="subject" type="hidden" value=""/>
# <input class="btn_search_all" onclick="nclk(this, 'sch.nx', '', '', 1); window.open('http://search.naver.com/search.naver?where=nexearch&amp;sm=sta_hty.terms&amp;ie=utf8&amp;query=' + encodeURIComponent(document.getElementById('term_query').value)); return false;" type="button" value="통합검색"/>
# </div>
# </fieldset>
# </form>
# </div>
# <div class="category_wrap" id="categoryWrap">
# <a class="btn_category" href="#" id="evt-global-navigation-button" onclick="nclk(this, 'STA.category', '', '', 1);" role="button"><span class="blind">카테고리 보기</span></a>
# <div class="ly_category">
# <div class="category_area">
# <div class="section topic">
# <strong class="title">주제백과</strong>
# <ul class="category_list">
# <li class="category_item">
# <a href="/list.naver?cid=50871&amp;categoryId=50871" onclick="nclk(this, 'mnu.themelist', '50871', '', 1);">건강백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=60195&amp;categoryId=60195" onclick="nclk(this, 'mnu.themelist', '60195', '', 1);">수학/과학백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=44630&amp;categoryId=44630" onclick="nclk(this, 'mnu.themelist', '44630', '', 1);">음식백과</a>
# </li>
# <li class="category_item">
# <a class="new" href="/list.naver?cid=44623&amp;categoryId=44623" onclick="nclk(this, 'mnu.themelist', '44623', '', 1);">미술백과<span class="blind">new</span></a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=46675&amp;categoryId=46675" onclick="nclk(this, 'mnu.themelist', '46675', '', 1);">동물백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=46676&amp;categoryId=46676" onclick="nclk(this, 'mnu.themelist', '46676', '', 1);">식물백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=60419&amp;categoryId=60419" onclick="nclk(this, 'mnu.themelist', '60419', '', 1);">문학백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=61278&amp;categoryId=61278" onclick="nclk(this, 'mnu.themelist', '61278', '', 1);">역사백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=60418&amp;categoryId=60418" onclick="nclk(this, 'mnu.themelist', '60418', '', 1);">음악백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=60196&amp;categoryId=60196" onclick="nclk(this, 'mnu.themelist', '60196', '', 1);">밀리터리백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=48677&amp;categoryId=48677" onclick="nclk(this, 'mnu.themelist', '48677', '', 1);">비주얼백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=51613&amp;categoryId=51613" onclick="nclk(this, 'mnu.themelist', '51613', '', 1);">동영상백과</a>
# </li>
# </ul>
# </div>
# <div class="section general">
# <strong class="title">종합백과</strong>
# <ul class="category_list">
# <li class="category_item">
# <a href="/list.naver?cid=40942&amp;categoryId=40942" onclick="nclk(this, 'mnu.synlist', '40942', '', 1);">두산백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=44621&amp;categoryId=44621" onclick="nclk(this, 'mnu.synlist', '44621', '', 1);">한국민족문화대백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=58737&amp;categoryId=58737" onclick="nclk(this, 'mnu.synlist', '58737', '', 1);">네이버캐스트</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=51792&amp;categoryId=51792" onclick="nclk(this, 'mnu.synlist', '51792', '', 1);">한국향토문화전자대전</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=49190&amp;categoryId=49190" onclick="nclk(this, 'mnu.synlist', '49190', '', 1);">문화원형백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=57623&amp;categoryId=57623" onclick="nclk(this, 'mnu.synlist', '57623', '', 1);">조선향토대백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=44625&amp;categoryId=44625" onclick="nclk(this, 'mnu.synlist', '44625', '', 1);">어린이백과</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=44626&amp;categoryId=44626" onclick="nclk(this, 'mnu.synlist', '44626', '', 1);">학생백과</a>
# </li>
# </ul>
# </div>
# <div class="section subject">
# <strong class="title">주제별 카테고리</strong>
# <ul class="category_list">
# <li class="category_item">
# <a href="/list.naver?cid=41697&amp;categoryId=41697" onclick="nclk(this, 'mnu.sbjlist', '41697', '', 1);">인문과학</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41698&amp;categoryId=41698" onclick="nclk(this, 'mnu.sbjlist', '41698', '', 1);">사회과학</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41699&amp;categoryId=41699" onclick="nclk(this, 'mnu.sbjlist', '41699', '', 1);">기술/공학</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41700&amp;categoryId=41700" onclick="nclk(this, 'mnu.sbjlist', '41700', '', 1);">자연과학</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41701&amp;categoryId=41701" onclick="nclk(this, 'mnu.sbjlist', '41701', '', 1);">문화예술</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41702&amp;categoryId=41702" onclick="nclk(this, 'mnu.sbjlist', '41702', '', 1);">생활/취미/스포츠</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41703&amp;categoryId=41703" onclick="nclk(this, 'mnu.sbjlist', '41703', '', 1);">역사/문화</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41704&amp;categoryId=41704" onclick="nclk(this, 'mnu.sbjlist', '41704', '', 1);">기관/단체</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=43702&amp;categoryId=43702" onclick="nclk(this, 'mnu.sbjlist', '43702', '', 1);">지역/국가</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=41706&amp;categoryId=41706" onclick="nclk(this, 'mnu.sbjlist', '41706', '', 1);">시사/상식/종합</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=50280&amp;categoryId=50280" onclick="nclk(this, 'mnu.sbjlist', '50280', '', 1);">용어해설</a>
# </li>
# <li class="category_item">
# <a href="/list.naver?cid=50279&amp;categoryId=50279" onclick="nclk(this, 'mnu.sbjlist', '50279', '', 1);">참여이미지</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="tlist_area" id="tlist_util_box">
# <p class="desc">
# <strong class="title">
# <a href="/tlist" onclick="nclk(this, 'mnu*k.main', '', '', 1);">
#                     지식리스트<i class="ico_beta"><span class="blind">Beta</span></i>
# </a>
# </strong>유용한 지식리스트를 만들어 지식백과 사용자들과 공유해보세요!
#         </p>
# <ul class="tlist_list">
# <li class="tlist_item">
# <a href="/tlist/?type=my" onclick="nclk(this, 'mnu*k.curate', '', '', 1);">
#                     만든리스트<em class="count __MY_CNT">999</em><i class="ico_arrow"></i>
# </a>
# </li>
# <li class="tlist_item">
# <a href="/tlist/?type=join" onclick="nclk(this, 'mnu*k.join', '', '', 1);">
#                     참여한 리스트<em class="count __JOIN_CNT">999</em><i class="ico_arrow"></i>
# </a>
# </li>
# <li class="tlist_item">
# <a href="/tlist/?type=like" onclick="nclk(this, 'mnu*k.like', '', '', 1);">
#                     좋아요 리스트<em class="count __LIKE_CNT">999</em><i class="ico_arrow"></i>
# </a>
# </li>
# <li class="tlist_item">
# <a href="/tlist/?type=history" onclick="nclk(this, 'mnu*k.read', '', '', 1);">
#                     최근에 본 리스트<em class="count __HISTORY_CNT">999</em><i class="ico_arrow"></i>
# </a>
# </li>
# </ul>
# </div>
# <a class="btn_close" href="#" onclick="nclk(this, 'mnu.close', '', '', 1);return false;" role="button">
# <span class="blind">카테고리 레이어 닫기</span>
# </a>
# </div>
# </div>
# </div>
# </div><div class="headword_wrap">
# <div class="headword_area">
# <div class="headword_info">
# <h2 class="title">
# <a href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'sca.sctitle', '', '', 1);">
# <span>철강용어사전</span></a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="container">
# <div id="content">
# <div class="path_area">
# <a class="path_link" href="/list.naver?categoryId=41699" onclick="nclk(this, 'csb.categorynavi', '', '', 1);">기술/공학</a>
# <a class="path_link" href="/list.naver?categoryId=42323" onclick="nclk(this, 'csb.categorynavi', '', '', 1);">기계/자동차/금속</a>
# <a class="path_link selected" href="/list.naver?categoryId=67995" onclick="nclk(this, 'csb.categorynavi', '', '', 1);">철강용어사전</a>
# <em class="count">6,915건</em>
# </div>
# <div class="cite_area_wrap active">
# <h3 class="blind">제공처 정보</h3>
# <div class="thumb_area">
# <div class="thumb">
# <a href="https://book.naver.com/bookdb/book_detail.nhn?bid=8751720" onclick="nclk(this, 'soc.simg', '', '', 1);" target="_blank">
# <img alt="철강용어사전 이미지" height="94" src="https://bookthumb-phinf.pstatic.net/cover/087/517/08751720.jpg?type=m96"/><span class="mask"></span>
# </a>
# </div>
# </div>
# <div class="cite_area">
# <div class="cite_info">
# <strong class="title">
#                     철강용어사전
#
#             </strong>
# <a class="link" href="https://book.naver.com/bookdb/book_detail.nhn?bid=8751720" onclick="nclk(this, 'soc.bmore', '', '', 1);" target="_blank">책보러가기<i class="ico_arrow"></i></a>
# </div>
# <p class="desc" }="">
#                 5,857개의 철강금속용어를 한글로 수록과 함께 대표적인 약어, 상품명 및 국내외 주요철강사 관련 단체를 실었다.
#             </p>
# </div>
# <div class="writer_area">
# <ul class="writer_list">
# <li>
# <div class="cite_area">
# <p class="writer_info">
# <strong>
#                                         제공처
#                                 </strong>
# <span class="writer">
# <a href="/list.naver?searchId=au7104" onclick="nclk(this, 'soc.expertname', '', '', 1);">에스앤엠미디어</a>
# </span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="toggle_area">
# <a class="btn_more" href="#">접기<i class="ico"></i></a>
# </div>
# </div>
# <div class="sort_area">
# <ul class="tab_list">
# <li class="tab_item selected"><a href="/list.naver?categoryId=67995&amp;so=st1.dsc&amp;viewType=&amp;categoryType=" onclick="nclk(this, 'tst.pv', '', '', 1);">주간조회순</a></li>
# <li class="tab_item"><a href="/list.naver?categoryId=67995&amp;so=date.dsc&amp;viewType=&amp;categoryType=" onclick="nclk(this, 'tst.new', '', '', 1);">최신순</a></li>
# <li class="tab_item"><a href="/list.naver?categoryId=67995&amp;so=st3.asc&amp;viewType=&amp;categoryType=" onclick="nclk(this, 'tst.kalphabet', '', '', 1);">가나다순</a></li>
# </ul>
# <div class="btn_area">
# <a class="btn_gallery" href="/imageViewer.naver?categoryId=67995&amp;so=st1.dsc&amp;index=&amp;mode=category" onclick="nclk(this, 'cti.imgal', '', '', 1);" target="_blank"><i class="ico"></i>이미지 갤러리</a>
# </div>
# <div class="layer_box" style="display:none;left:640px;">해당 목록 내 전체<br/>이미지들을 볼 수 있습니다.<a class="btn_close" href="#" id="closeBtnGallery">레이어창 닫기</a><em class="bg"></em></div></div> <div class="list_wrap">
# <ul class="content_list">
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6204627&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">제1류위험물</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6204627" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					(산화성고체) 강산화성 물질로 상온에서 고체상태이고 마찰충격으로 많은 산소를 방출할 수 있는 물질로 이루어진 위험물을 말한다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6204627" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">12,210</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6201629&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">연신율 [elongation, percentage elongation]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6201629" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					1. 인장시험편의 표점간 길이와 원래의 표점거리와의 차. 이 차를 표점 거리에 대한 비(변형) 또는 백분율로서 표시하는 경우가 많다. 2. 전 연신율, 파단연신율과 같음.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6201629" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">17,845</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6204647&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">제연설비 [Control Flow]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6204647" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					건축물의 화재시 건축물 내에 수용되어 있는 사람들을 안전한 장소로 신속하게 피난 또는 대피할 수 있도록 함과 동시에 건축물 내에 가연물질의 연소생성물인 연기가 충만되어 있어 소화업무가 원활하지 못하게 되어 화재가 확대되므로 정상적인 소화가 이루어질 수 있도록 지하 1층 등에 설치하여 건축물의 외부로 연기를 배출시키는 설비이다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6204647" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">16,666</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6201558&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">연결살수설비</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6201558" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					연결 살수설비는 지하가 또는 건축물의 지하층의 연면적이 150m2 이상인 곳에 설치하는 본격 소화를 위한 소화활동상 필요한 설비로서, 건축물의 지하층은 화재가 발생할 경우 연소생성물인 연기가 외부로 쉽게 배출되지 않아 소화활동에 지장을 초래하므로 초기 소화용으로 설치된 옥내소화전 설비만으로는 화재의 소화가 어려워 건축물의 1층벽에 설치된 연결살수 설비용의 송수구로 수원을 공급받아 사용하도록 되어있는 설비를 말한다. · 설비구성: 송수구, 배관, 방수구 등은 물분무설비 및 스프링클러 설비와 동일함.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6201558" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">19,265</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6204189&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">특정잔류탄소함유율탈탄층깊이 [decarburized depth with specified residual carbon ratio]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6204189" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					표면으로부터 어떤 일정한 잔류탄소 함유율(소지의 탄소농도에 대해, 잔존하고 있는 탄소농도의 비율)을 갖는 위치까지의 거리. 이 경우의 잔류 탄소 함유율은 조직에서 판정한다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6204189" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">150</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6202559&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">재고회전율</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6202559" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					재고가 연간 몇 번 회전하는가를 산정한 것으로, 「연간 입고량÷월간재고량」의 산식을 이용한다. 시황이 호조일 때는 회전율이 빠르고, 그 반대일 경우에는 느리다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6202559" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">19,718</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="thumb_area">
# <div class="thumb id6207910">
# <a href="/entry.naver?docId=6207910&amp;cid=67995&amp;categoryId=67995">
# <img alt="선재" class="lazyLoadImage" data-id="id6207910" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210120140701459_E3I3A4KM4.jpg%2Fdh2_g_237_i1.jpg%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=10" onerror="this.className='listThumbnail'" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/>
# <span class="mask"></span>
# </a>
# <a class="photo_more" data-areacode="tml" href="#">
# <i class="ico"></i><strong>1</strong>
# <span class="blind">개의 이미지 미리보기</span>
# </a>
# </div>
# <div class="id6207910 ly_image_view" style="display:none">
# <div class="image_area">
# <a href="/entry.naver?docId=6207910&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.img', '', '', 1);"><img alt="선재" class="lazyLoadImage" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210120140701459_E3I3A4KM4.jpg%2Fdh2_g_237_i1.jpg%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=10" onerror="this.src='https://ssl.pstatic.net/static/terms/terms/img/noimg.gif';if(this.nextSibling)this.nextSibling.style.display='none';" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/></a>
# <a href="/entry.naver?docId=6207910&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.img', '', '', 1);"><img alt="선재" class="lazyLoadImage" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210115122535776_SBVKFRVR7.png%2Fdh2_h_616_i1.png%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=10" onerror="this.src='https://ssl.pstatic.net/static/terms/terms/img/noimg.gif';if(this.nextSibling)this.nextSibling.style.display='none';" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/></a>
# </div>
# </div>
# </div>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6207910&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">선재 [wire rods]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6207910" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					봉상으로 열간 압연된 강철로서 코일상으로 감긴 강재. 단면의 모양은 원형, 정방형, 육각형 및 특수한 모양을 갖는 이형 선재 등이 포함된다. 또한 용도에 따라 바인코일이라고도 한다. 장척 봉강을 말아 놓은 바인코일과 외관은 같지만 이 둘은 재질과 용도에 있어서 구분된다. 보통 선재와 특수 선재로 대별되어, KS에서는 강종에 따라 연강 선재와 경강 선재로 나누고, 다시 특수 용도용 피막 아크용접봉 심선용 선재와 피아노 선재를 규정하고 있다. 치수는 단면의 직경(선경)으로 표시되며 mm로 호칭된다. 경 5.558mm(0.20인치)가 표준품으로 바인코일로는 최대경 42mm까지 제조된다. 선재의 특성은 다양한 용도, 반제품에서 제품화될 때까지의 공정이 길며, 신선이나 가공등 후속공정이 요구되기 때문에 가공방법에 따라 품질수준이 달라진다. 보통강선재중 연강선재는 못, 철사, 철망 등에 쓰이고, 경강선재는 와이어로프 등에 쓰인다. 특수강 선재는 나사, 볼트, 너트, 샤프트, 기어류에
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6207910" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">18,698</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6204055&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">제4류위험물</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6204055" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					(인화성액체) 가연성물질로서 인화성 증기를 발생하는 액체위험물로 흔히 기름이라 말하는 것으로 액체연료 및 여러 물질을 녹이는 용제 등으로 일상생활 및 산업분야 등에 많이 이용되고 있다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6204055" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">13,879</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="thumb_area">
# <div class="thumb id6206783">
# <a href="/entry.naver?docId=6206783&amp;cid=67995&amp;categoryId=67995">
# <img alt="슬리터" class="lazyLoadImage" data-id="id6206783" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210120140756060_P7PTSBKSU.jpg%2Fdh2_g_805_i1.jpg%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=10" onerror="this.className='listThumbnail'" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="id6206783 ly_image_view" style="display:none">
# <div class="image_area">
# <a href="/entry.naver?docId=6206783&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.img', '', '', 1);"><img alt="슬리터" class="lazyLoadImage" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210120140756060_P7PTSBKSU.jpg%2Fdh2_g_805_i1.jpg%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=10" onerror="this.src='https://ssl.pstatic.net/static/terms/terms/img/noimg.gif';if(this.nextSibling)this.nextSibling.style.display='none';" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/></a>
# </div>
# </div>
# </div>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6206783&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">슬리터 [slitter]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6206783" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					스트립 코일의 양 끝을 잘라서 정돈하든가, 또는 폭이 긴 방향으로 여러 가닥으로 절단하기 위해 사용되는 기계.(그림 참조) 슬리팅공정
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6206783" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">10,778</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="thumb_area">
# <div class="thumb id6201982">
# <a href="/entry.naver?docId=6201982&amp;cid=67995&amp;categoryId=67995">
# <img alt="후판" class="lazyLoadImage" data-id="id6201982" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210115123032278_WV5Z0YLQB.png%2Fdh2_n_322_i1.png%3Ftype%3Dw450_fst_n%22&amp;twidth=226&amp;theight=226&amp;opts=17" onerror="this.className='listThumbnail'" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="id6201982 ly_image_view" style="display:none">
# <div class="image_area">
# <a href="/entry.naver?docId=6201982&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.img', '', '', 1);"><img alt="후판" class="lazyLoadImage" data-src="https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5938_000_1%2F20210115123032278_WV5Z0YLQB.png%2Fdh2_n_322_i1.png%3Ftype%3Dw450_fst_n%22&amp;twidth=113&amp;theight=113&amp;opts=17" onerror="this.src='https://ssl.pstatic.net/static/terms/terms/img/noimg.gif';if(this.nextSibling)this.nextSibling.style.display='none';" src="https://ssl.pstatic.net/static/terms/terms/img/e.gif"/></a>
# </div>
# </div>
# </div>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6201982&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">후판 [plate]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6201982" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					두께 3mm이상의 강판을 말하는 것으로, 3mm미만의 박판과 구별된다. 후판 중에서 두께 3mm이상 6mm미만의 것은 특히 중(후)판이라 불린다. 미터법의 실시에 의해 두께, 폭, 길이 모두 mm로 불리우게 되었으나 정척물의 폭과 길이에 대해서는 이제까지의 관용 때문에 피트(ft.)가 병용된다. 재질에 따라 일반구조용, 용접용, 보일러용, 대(구)경 강관용 등으로 규격을 정해놓고 있다. 또한 용도로는 조선용, 보일러용, 바닥용 외에 표면 형상이 특수한 무늬판, 후판을 모재로 하는 클래드 강판(접합강판)이 있다. 후판
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6201982" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# ...
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">9,920</em></span></div>
# </div>
# </div>
# </li>
# <li>
# <div class="info_area">
# <div class="subject">
# <strong class="title">
# <a href="/entry.naver?docId=6202472&amp;cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.termlist', '', '', 1);">표면조도(거칠기) [surface roughness]</a>
# <a class="btn_txt __TLIST_PUT" data-contentsid="6202472" data-servicecode="TERMS" href="#" onclick="nclk(this, 'tml.kadd','', '', 1)">담기</a>
# </strong>
# </div>
# <p class="desc __ellipsis" style="overflow:hidden;max-height:66px">
# 					기계 표면의 미세한 요철. 표면조도의 표시방법에는 여러 가지가 있는데, 최대높이(Rmax), 십점평균거칠기(Rz) 및 중심선평균거칠기(Ra)의 3가지가 규정되어 있다. 기계표면의 조도는 비파괴검사의 정도, 마모의 진행 정도 등 다른 부품의 강도에도 영향을 주는 경우가 있으므로, 주의하지 않으면 안된다. 특히 응력집중부에는 설계형상에 의해 계산된 응력집중에 가공점(바이트점, 연마점)에 의한 응력집중이 겹쳐 뜻하지 않은 사고로 이어지는 경우가 있다. 이러한 부분의 가공에 있어서는 응력의 부하 방법을 고려하여 가공방향을 정하고, 경면(鏡面) 연마해서 안전을 꾀하기도 한다.
# 				</p>
# <div class="related v2">
# <div class="iner"><span class="info book"><a "="" href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'tml.source', '', '', 1);">철강용어사전</a></span><span class="info"> <div class="_reactionModule u_likeit type_layer" data-cid="6202472" data-sid="ENCYCLOPEDIA" style="visibility: hidden;display:none">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="javascript:;" role="button">
# <span class="u_likeit_icons u_ico _icon">
# <span class="u_likeit_icon __reaction__zeroface" style="z-index: 5;"><span class="u_likeit_blind">0</span></span>
# </span>
# <span class="u_likeit_blind" id="u_likeit_title">좋아요 평가하기</span>
# <span class="u_likeit_text num _count">{label}</span>
# </a>
# <ul aria-labelledby="u_likeit_title" class="u_likeit_layer _faceLayer" role="radiogroup">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#ratingbutton-useful" role="button">
# <span class="u_likeit_list_name _label">유익해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#ratingbutton-want" role="radio">
# <span class="u_likeit_list_name _label">더 알고 싶어요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list quote" role="menuitem">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.quote|RTL.unquote" data-type="quote" href="#ratingbutton-quote" role="radio">
# <span class="u_likeit_list_name _label">담아갈게요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list modify" role="presentation">
# <a aria-checked="false" class="u_likeit_list_button _button" data-log="RTL.modify|RTL.unmodify" data-type="modify" href="#ratingbutton-modify" role="radio">
# <span class="u_likeit_list_name _label">수정해주세요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# </span><span class="info"><i class="ico_see"></i><span class="blind">조회</span><em class="count">5,192</em></span></div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="paginate" id="paginate">
# <span class="prev disabled"><a href="#" onclick="return false;">이전</a><i class="ico_bar"></i></span>
# <strong>1</strong>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=2" onclick="nclk(this, 'pag.paging', '', '2', 1)">2</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=3" onclick="nclk(this, 'pag.paging', '', '3', 1)">3</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=4" onclick="nclk(this, 'pag.paging', '', '4', 1)">4</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=5" onclick="nclk(this, 'pag.paging', '', '5', 1)">5</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=6" onclick="nclk(this, 'pag.paging', '', '6', 1)">6</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=7" onclick="nclk(this, 'pag.paging', '', '7', 1)">7</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=8" onclick="nclk(this, 'pag.paging', '', '8', 1)">8</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=9" onclick="nclk(this, 'pag.paging', '', '9', 1)">9</a>
# <a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=10" onclick="nclk(this, 'pag.paging', '', '10', 1)">10</a>
# <span class="next"><i class="ico_bar"></i><a href="/list.naver?cid=67995&amp;categoryId=67995&amp;page=11" onclick="nclk(this, 'pag.next', '', '', 1);">다음</a></span>
# </div>
# </div>
# <div class="aside" id="asideWrap" role="complementary">
# <div class="section active">
# <h3 class="section_title">연관 목록</h3>
# <ul class="section_list">
# <li class="section_item">
# <a href="/list.naver?cid=42323&amp;categoryId=42323" onclick="nclk(this, 'rrl.source', '', '', 1);">기계/자동차/금속</a>
# <ul class="category_list">
# <li class="section_item">
# <a href="/list.naver?cid=51390&amp;categoryId=51390" onclick="nclk(this, 'rrl.source', '', '', 1);">섀시는 이렇게 되어 있다</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=51389&amp;categoryId=51389" onclick="nclk(this, 'rrl.source', '', '', 1);">엔진은 이렇게 되어 있다</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=42330&amp;categoryId=42330" onclick="nclk(this, 'rrl.source', '', '', 1);">자동차 용어사전</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=58408&amp;categoryId=58408" onclick="nclk(this, 'rrl.source', '', '', 1);">나도 튜닝 한번 해볼까?</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=42331&amp;categoryId=42331" onclick="nclk(this, 'rrl.source', '', '', 1);">최신자동차공학시리즈</a>
# </li>
# <li class="section_item selected">
# <a href="/list.naver?cid=67995&amp;categoryId=67995" onclick="nclk(this, 'rrl.source', '', '', 1);">철강용어사전</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=55630&amp;categoryId=55630" onclick="nclk(this, 'rrl.source', '', '', 1);">철도차량도감</a>
# </li>
# <li class="section_item">
# <a href="/list.naver?cid=51087&amp;categoryId=51087" onclick="nclk(this, 'rrl.source', '', '', 1);">한국의 배</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="section" id="sourceProvider">
# <h3 class="section_title">정보 제공처</h3>
# <ul class="section_list">
# <li class="section_item">
# <a href="/list.naver?categoryId=67995" onclick="nclk(this, 'csa.source', '', '', 1);">철강용어사전</a>
# <em class="cite">
# <a href="/list.naver?searchId=au7104" onclick="nclk(this, 'csa.provider', '', '', 1);">에스앤엠미디어</a>
# </em>
# </li>
# </ul>
# </div>
# </div>
# <a class="goto_top btn_top" href="#" id="goto_top" onclick="window.scrollTo(0,0);nclk(this, 'bdr.top', '', '', 1);return false"><span class="blind">위로가기</span></a></div>
# <hr/>
# <div id="footer" role="contentinfo">
# <div class="dic_wrap" id="dictionaryCategories">
# <div class="dic_area">
# <h3 class="dic_title">주제백과</h3>
# <div class="dic_iner">
# <ul class="dic_list">
# <li class="dic_item" data-idx="0"><a href="/list.naver?cid=50871&amp;categoryId=50871" onclick="nclk(this, 'pct.list', '', '', 1);">건강백과</a></li>
# <li class="dic_item" data-idx="1"><a href="/list.naver?cid=60195&amp;categoryId=60195" onclick="nclk(this, 'pct.list', '', '', 1);">수학/과학백과</a></li>
# <li class="dic_item" data-idx="2"><a href="/list.naver?cid=44630&amp;categoryId=44630" onclick="nclk(this, 'pct.list', '', '', 1);">음식백과</a></li>
# <li class="dic_item" data-idx="3"><a href="/list.naver?cid=44623&amp;categoryId=44623" onclick="nclk(this, 'pct.list', '', '', 1);">미술백과</a></li>
# <li class="dic_item" data-idx="4"><a href="/list.naver?cid=46675&amp;categoryId=46675" onclick="nclk(this, 'pct.list', '', '', 1);">동물백과</a></li>
# <li class="dic_item" data-idx="5"><a href="/list.naver?cid=46676&amp;categoryId=46676" onclick="nclk(this, 'pct.list', '', '', 1);">식물백과</a></li>
# <li class="dic_item" data-idx="6"><a href="/list.naver?cid=60419&amp;categoryId=60419" onclick="nclk(this, 'pct.list', '', '', 1);">문학백과</a></li>
# <li class="dic_item" data-idx="7"><a href="/list.naver?cid=61278&amp;categoryId=61278" onclick="nclk(this, 'pct.list', '', '', 1);">역사백과</a></li>
# <li class="dic_item line_change" data-idx="8"><a href="/list.naver?cid=60418&amp;categoryId=60418" onclick="nclk(this, 'pct.list', '', '', 1);">음악백과</a></li>
# <li class="dic_item" data-idx="9"><a href="/list.naver?cid=60196&amp;categoryId=60196" onclick="nclk(this, 'pct.list', '', '', 1);">밀리터리백과</a></li>
# <li class="dic_item" data-idx="10"><a href="/list.naver?cid=48677&amp;categoryId=48677" onclick="nclk(this, 'pct.list', '', '', 1);">비주얼백과</a></li>
# <li class="dic_item" data-idx="11"><a href="/list.naver?cid=51613&amp;categoryId=51613" onclick="nclk(this, 'pct.list', '', '', 1);">동영상백과</a></li>
# </ul>
# </div>
# <a class="btn_more" href="/category.naver" onclick="nclk(this, 'pct.more', '', '', 1);">더보기</a>
# </div>
# </div><div class="info_wrap">
# <ul class="info_list">
# <li><a href="https://policy.naver.com/rules/service.html" onclick="nclk(this, 'fot.agreement', '', '', 1);" target="_blank">이용약관</a></li>
# <li><a href="https://help.naver.com/alias/terms/terms_new2.naver" onclick="nclk(this, 'fot.cs', '', '', 1);" target="_blank">지식백과 고객센터</a></li>
# <li><a href="https://help.naver.com/alias/terms/terms_new1.naver" onclick="nclk(this, 'fot.modify', '', '', 1);" target="_blank">콘텐츠 수정</a> 및 <a href="https://help.naver.com/alias/terms/terms_new3.naver" onclick="nclk(this, 'fot.report', '', '', 1);" target="_blank">오류신고</a></li>
# <li><a href="https://www.navercorp.com/ko/company/proposalGuide.nhn" onclick="nclk(this, 'fot.contact', '', '', 1);" target="_blank">제휴제안</a></li>
# <li><a href="https://policy.naver.com/rules/privacy.html" onclick="nclk(this, 'fot.privacy', '', '', 1);" target="_blank"><strong>개인정보처리방침</strong></a></li>
# <li><a href="/tlist/guide.naver" onclick="nclk(this, 'fot.policy', '', '', 1);" target="_blank">지식리스트 운영원칙</a></li>
# <li><a href="https://policy.naver.com/rules/disclaimer.html" onclick="nclk(this, 'fot.disclaimer', '', '', 1);" target="_blank">책임의 한계와 법적고지</a></li>
# </ul>
# <address>
# <a class="logo" href="https://www.navercorp.com/" onclick="nclk(this, 'fot.naver', '', '', 1);" target="_blank">NAVER</a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com/" onclick="nclk(this, 'fot.naver', '', '', 1);" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div></div>
# <script type="text/javascript">
# </script>
# <script>
# 	var commonData = {
# 		autocompleteUrl: 'https://ac.terms.naver.com/ac',
# 		urlForEncode: 'https://terms.naver.com/list.naver?cid=67995&categoryId=67995',
# 		lcsObject : {},
# 		themelist: {
# 			jsApiPc: '/tlist/api/js/tlist.js?240213064516',
# 			themelistDomainPc: '',
# 			cacheBustingParam: '240213064516',
# 			indexType: '',
# 			isMobile: false,
# 			isThemeList: false,
# 			detailTypePage: ''
# 		}
# 	}
# </script><script>
#   var entryData = {
#     isLogin: false,
#     loginUrl: "https://nid.naver.com/nidlogin.login?url=" + encodeURIComponent(document.URL),
#     isImageLibrary: false,
#     entry: {
#       likeDomain: "https://common.like.naver.com",
#       likeScriptUrl: "https://common.like.naver.com/js/reaction/dist/reaction.min.js?240213064516",
#       likeListApi: "https://common.like.naver.com",
#       hasLnbLike: false
#     },
#     themelist: {
#       jsApiPc: "/tlist/api/js/tlist.js?240213064516",
#       themelistDomainPc: "",
#       cacheBustingParam: "240213064516",
#       indexType: "",
#       isMobile: false,
#       isThemeList: false,
#       detailTypePage: ""
#     },
#     serviceId: "TERMS",
#     docId: null,
#     dicName: "null",
#     isPrintPage: false,
#     categoryId: "67995",
#     videoLength: "0",
#     relatedImageLength: "0",
#     diffMeaning: {
#       groupTitle: "null",
#       groupId: "null"
#     },
#     hasAudioInfra: false,
#     audioPartnerKey: "1a72f991",
#     audioPartnerId: "terms-web",
#     soundLength: 0,
#     audioApiDomain: "https://static-audiop.pstatic.net/audiocloud-webplayercore/1.1.1.0/js/audiocloud_webplayer_core.js?240213064516",
#     images: {
#       hasImage: false,
#       thumbnailData: null
#     },
#     naverMap: {
#       hasNaverMap: false,
#       naverMapManagerData: [
#
#       ]
#     },
#     isNotPreviewPage: true,
#     tkListId: "null",
#     htmlEscapedQuery: '',
#     isVisualDic: false,
#     font: {
#       defaultLevel: "",
#       fontSize: ""
#     },
#     preventContextMenu: false,
#     isTermsExplanation: false,
#     termSource: '<p style="$$margin$$;padding:0;font-size:12px;font-family:Dotum;font-style:normal;font-weight: normal;color:black;"><strong style="padding:0 7px 0 0;color:black;font-weight:bold;font-size:12px;">[네이버 지식백과]</strong> <a href=\"https://terms.naver.com/entry.naver?docId=\"></a></p>',
#     hasNotNewAudioInfra: true,
#     tooltipApi: "https://ssl.pstatic.net/dicimg/tip/tip_pc.js",
#     namlDocType: false,
#     hasRepresentImage: false,
#     denyRightClick: false,
#     isSe3: false,
#
#     se3Script: "https://ssl.pstatic.net/static.editor/static/viewer/common/se_init.min.js?d=",
#
#     scrollData: {
#       query: "",
#       subject: "",
#       tab: "",
#       page: 1,
#       totalCount: 0
#     },
#     diffData: {
#       title: "",
#       query: "",
#       delimiter: ""
#     },
#     hasImageThumbnails: true,
#     isMedicalQuery: false,
#     isMusicQuery: false,
#     env: "release",
#     devNamlMinJs: "https://stage-api.naf.naver.com/2.0/js/naml.min.js?v=240213064516",
#     devNamlModuleMinJs: "https://stage-api.naf.naver.com/2.0/js/naml.module.min.js?v=240213064516",
#     stageNamlMinJs: "https://stage-api.naf.naver.com/2.0/js/naml.min.js?v=240213064516",
#     stageNamlModuleMinJs: "https://stage-api.naf.naver.com/2.0/js/naml.module.min.js?v=240213064516",
#     namlMinJs: "https://api.naf.naver.com/2.0/js/naml.min.js?v=240213064516",
#     namlModuleMinJs: "https://api.naf.naver.com/2.0/js/naml.module.min.js?v=240213064516",
#     naverWebPlayer: {
#       rmcVideoInitScript: '',
#       vid: '',
#       inKey: '',
#       videoPlayer: '',
#       width: 0,
#       height: 0
#     },
#     isSummary: false
#   }
# </script><script data-main="/js/pc/dist/list.min.js?lm=240213064516" src="/js/lib/require.min.js"></script>
# </body>
# </html>

# %%
words = soup.select('.title > a:nth-child(1)')

# %%
words[2].text
# Out:
# '제1류위험물'

# %%
for word in words[2:]:
    print(word.text)
# Out:
# 제1류위험물
# 연신율 [elongation, percentage elongation]
# 제연설비 [Control Flow]
# 연결살수설비
# 특정잔류탄소함유율탈탄층깊이 [decarburized depth with specified residual carbon ratio]
# 재고회전율
# 선재 [wire rods]
# 제4류위험물
# 슬리터 [slitter]
# 후판 [plate]
# 자위소방대
# 핀홀 [pin hole]
# Top-Down공법
# 옥내소화전설비 [Open Loop]
# 표면조도(거칠기) [surface roughness]

# %% [markdown]
# ### 철강용어사전 1page~10page 단어 타이틀 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup as bs4

url = 'https://terms.naver.com/list.naver'
p = {'cid': '67995', 'categoryId' : '67995'}
res = requests.get(url,params=p)
soup=bs4(res.text, 'html.parser')
soup

results = []
for i in range(1,11):
    print('{}페이지 크롤링 중입니다....'.format(i), end='\r')
    url = 'https://terms.naver.com/list.naver?cid=67995&categoryId=67995&page='+str(i)
    res = requests.get(url)
    soup=bs4(res.text, 'html.parser')
    words = soup.select('.title > a:nth-child(1)')[2:]
    for word in words:
        print(word.text)
# Out:
# 제1류위험물롤링 중입니다....
# 연신율 [elongation, percentage elongation]
# 제연설비 [Control Flow]
# 연결살수설비
# 특정잔류탄소함유율탈탄층깊이 [decarburized depth with specified residual carbon ratio]
# 재고회전율
# 선재 [wire rods]
# 제4류위험물
# 슬리터 [slitter]
# 후판 [plate]
# 자위소방대
# 핀홀 [pin hole]
# Top-Down공법
# 옥내소화전설비 [Open Loop]
# 표면조도(거칠기) [surface roughness]
# 송유관 [line pipe]..
# 오스테나이트 [austenite]
# 복공판
# 앵글 [angle]
# 어큐뮬레이터 [accumulator]
# 열팽창계수 [thermal expansion coefficient]
# 와이어로프 [wire rope]
# 전기아연도금강판 [electrolytic galvanized iron]
# 지적확인
# 전기강판 [flat rolled magnetic steel sheets and strip]
# 주조 [casting]
# 생석회 [CaO]
# 물질안전보건자료 [Material Safety Data Sheet]
# 분말소화기 [Quarterly Production Planning]
# 이산화탄소 소화기 [CO2 Tooth Flank]
# 포엠 [4 M, Traffic Control Controller]
# 대손
# 단중 [unit weight]
# 스테인리스강 [stainless steel]
# 자위소방대훈련
# 평탄도 [flatness]
# 금속조직현미경 [metallurgical microscope]
# FCAW원리 [Flux Cored Arc Welding]
# 중성점접지저항 [Neutral Grounding Resistor]
# 메탄 [methane]
# 동점도 [kinematic viscosity]
# 철 [iron, Fe]
# 납사 [naphtha]
# 스카핑 [scarfing]
# 안전변 [Safety Valve]
# 경도 [Hardness]....
# 증류 [distillation]
# 롤포밍 [roll forming]
# 봉강 [steel bar]
# TMCP강 [thermo mechanical control process steel]
# 코크스 건식소화 [Coke Dry Quenching]
# 클레임 [claim]
# ASME [American Society of Mechanical Engineers]
# 전연성 [展延性, punch stretchability]
# 배관용강관 [line pipes]
# 규사 [silica sand]
# 안전보건표지 [Safety Valve]
# 직접환원철 [direct reduction iron]
# 연소범위
# 염수분무시험 [salt spray test]
# 제선공정 크롤링 중입니다....
# 시간가중평균농도 [Time Weighted Average]
# 크리프시험 [creep test]
# 연필경도시험 [pencil hardness test]
# 로로선 [Roll On/Roll off]
# 소방시설
# 박판 [sheet]
# 냉간단조 [cold forging]
# 로크웰경도 [Rockwell hardness]
# 스텔라이트 [stellite]
# 압연 [rolling]
# 냉동톤 [Ton of Refrigeration]
# 평형상태도 [equilibrium phase diagram]
# 열간단조 [hot forging]
# 독성가스
# 피닝 [peening]다....
# 소성
# 선급협회
# 시안 [Cyanide]
# 가스크로마토그래피 분석 [gas chromatography]
# 데크플레이트 [steel deck plate]
# 나사산 [screw thread]
# 탄소당량 [carbon equivalent]
# 도수율 [Frequency Rate Injury]
# 로크웰경도시험 [Rockwell hardness test]
# 내력 [耐力, yield point, proof stress]
# LFG
# LD-AC법 [LD-AC process]
# 워싱 [washing]
# 제6류위험물
# 선로정수 [Line Constant]
# 엘리베이터 가이드레일 [elevator guide rail]
# 조질압연 [skin-pass, temper rolling]
# 연마 [grinding]
# 구조용강재 [steel for structural]
# 커플링 [coupling]
# 차아염소산소다 [NaOCl]
# 진직도 [Straightness]
# 소성로(펠릿의) [firing furnace]
# 철손 [watt loss]
# 워시프라이머 [wash primer]
# 직행률 [直進法]
# 후처리 [after treatment]
# 절대점도 [absolute viscosity]
# 경량형강 [light gauge steel]
# 딜러 [dealer]니다....
# 용융아연도금강판 [hot dipped galvanized iron]
# PVD [physical Vapor Deposition]
# 내화물 [refractory]
# 고압배관용 탄소강관 [carbon steel pipes for high pressure service]
# 진공열처리 [vacuum heat treatment]
# 점적률 [space factor]
# 공형 [pass, caliber, kaliber]
# 터닝센터 [Turning Center]
# 샤르피충격시험편 [test piece for Charpy impact test]
# 융점 [melting point]
# 커널 [Kernel]
# 응력변형선도 [stress-strain diagram]
# 취부 [Clamping]
# 맨드릴 [mandrel]
# 기계구조용 탄소강 [carbon steel for machine structural use]
# 선택밸브 [Selection Valve]
# 강관말뚝
# 권상장치 [Hoisting]
# 저합금강 [low alloy steel]
# 권취기 [coiler, reel]
# 수퍼듀플렉스 스테인리스강 [Super Duplex STS Steel]
# Ar″변태 [Ar″transformation]
# 중장기생산계획 [Mid-Long Term Production Planning]
# 위험예지훈련
# 스트립 [strip]
# 아연도금강판 [galvanized steel sheet, zinc coated steel sheet]
# 단조품 [as forged products]
# 전자변 [Solenoid Valve]
# 블루잉 [bluing]
# 메탄올 [methanol]....
# 밀링작업 [Milling Working]
# 앗차사고 [Near Miss]
# 합금강 [alloy steel]
# 워드레오나드제어 [Ward-Leonard control]
# 포항산업과학연구원 [Research Institute of Industrial Science & Technology]
# 철도용레일 [railway rails]
# 조관기
# 아키텍쳐 [Architecture]
# 하스텔로이 [Hastelloy]
# 방청프라이머 [rust preventive primer]
# 강재
# 재결정온도 [recrystallization temperature]
# 암모니아 [ammonia]
# 변태점 [transformation temperature, transformation point]
